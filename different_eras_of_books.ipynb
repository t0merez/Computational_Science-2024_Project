# %%
import coding_for_project

# %% [markdown]
# **Making lists of URLS of books from different eras.**

# %% [markdown]
# **1700\-1800**

# %%
era1700_1800 = []
era1700_1800.append("https://www.gutenberg.org/cache/epub/27744/pg27744.txt")# Remarks on Clarissa (1749) by Sarah Fielding
era1700_1800.append("https://www.gutenberg.org/cache/epub/4085/pg4085.txt")# The Adventures of Roderick Random by T. Smollett
era1700_1800.append("https://www.gutenberg.org/cache/epub/43520/pg43520.txt")# The Works of Henry Fielding, vol. 11 by Henry Fielding
era1700_1800.append("https://www.gutenberg.org/cache/epub/2160/pg2160.txt")# The Expedition of Humphry Clinker by T. Smollett
era1700_1800.append("https://www.gutenberg.org/cache/epub/804/pg804.txt")# A Sentimental Journey Through France and Italy by Laurence Sterne
era1700_1800.append("https://www.gutenberg.org/cache/epub/1292/pg1292.txt")# The Way of the World by William Congreve
era1700_1800.append("https://www.gutenberg.org/cache/epub/128/pg128.txt")# The Arabian Nights Entertainments
era1700_1800.append("https://www.gutenberg.org/cache/epub/35688/pg35688.txt")# Alice in Wonderland by Lewis Carroll and Alice Gerstenberg
era1700_1800.append("https://www.gutenberg.org/cache/epub/9182/pg9182.txt")# Villette by Charlotte Brontë
era1700_1800.append("https://www.gutenberg.org/cache/epub/1022/pg1022.txt")# Walking by Henry David Thoreau

# %% [markdown]
# **1800\-1900**

# %%
era1800_1900 = []
era1800_1900.append("https://www.gutenberg.org/cache/epub/10724/pg10724.txt")# The Store Boy by Jr. Horatio Alger
era1800_1900.append("https://www.gutenberg.org/cache/epub/84/pg84.txt")# Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley
era1800_1900.append("https://www.gutenberg.org/cache/epub/2701/pg2701.txt")# Moby Dick; Or, The Whale by Herman Melville
era1800_1900.append("https://www.gutenberg.org/cache/epub/21223/pg21223.txt")# The Carbonels by Charlotte M. Yonge
era1800_1900.append("https://www.gutenberg.org/cache/epub/30970/pg30970.txt")# Miss Cayley's Adventures by Grant Allen
era1800_1900.append("https://www.gutenberg.org/cache/epub/23853/pg23853.txt")# Ran Away to Sea by Mayne Reid
era1800_1900.append("https://www.gutenberg.org/cache/epub/120/pg120.txt")# Treasure Island by Robert Louis Stevenson
era1800_1900.append("https://www.gutenberg.org/cache/epub/730/pg730.txt")# Oliver Twist by Charles Dickens
era1800_1900.append("https://www.gutenberg.org/cache/epub/902/pg902.txt")# The Happy Prince, and Other Tales by Oscar Wilde
era1800_1900.append("https://www.gutenberg.org/cache/epub/1064/pg1064.txt")# The Masque of the Red Death by Edgar Allan Poe

# %% [markdown]
# **1900\-2000**

# %%
era1900_2000 = []
era1900_2000.append("https://www.gutenberg.org/cache/epub/42796/pg42796.txt")# The Box-Car Children by Gertrude Chandler Warner
era1900_2000.append("https://www.gutenberg.org/cache/epub/67979/pg67979.txt")# The Blue Castle: a novel by L. M. Montgomery
era1900_2000.append("https://www.gutenberg.org/cache/epub/64317/pg64317.txt")# The Great Gatsby by F. Scott Fitzgerald
era1900_2000.append("https://www.gutenberg.org/cache/epub/14907/pg14907.txt")# Living Alone by Stella Benson
era1900_2000.append("https://www.gutenberg.org/cache/epub/71152/pg71152.txt")# A lady and her husband by Amber Reeves Blanco White
era1900_2000.append("https://www.gutenberg.org/cache/epub/72824/pg72824.txt")# The mystery of the Blue Train by Agatha Christie
era1900_2000.append("https://www.gutenberg.org/cache/epub/4300/pg4300.txt")# Ulysses by James Joyce
era1900_2000.append("https://www.gutenberg.org/cache/epub/72869/pg72869.txt")# Meet the Tiger by Leslie Charteris
era1900_2000.append("https://www.gutenberg.org/cache/epub/32032/pg32032.txt")# Second Variety by Philip K. Dick
era1900_2000.append("https://www.gutenberg.org/cache/epub/58866/pg58866.txt")# The Murder on the Links by Agatha Christie

# %% [markdown]
# **Data Processing**

# %%
coding_for_project.draw_histogram(coding_for_project.dictOfLengthsMultiple(era1700_1800))

# %%
coding_for_project.draw_histogram(coding_for_project.dictOfLengthsMultiple(era1800_1900))

# %%
coding_for_project.draw_histogram(coding_for_project.dictOfLengthsMultiple(era1900_2000))

# %% [markdown]
# **Calculation of geometric distance between graphs to check if there is a difference**

# %%
dict1700_1800 = coding_for_project.dictOfLengthsMultiple(era1700_1800)
dict1800_1900 = coding_for_project.dictOfLengthsMultiple(era1800_1900)
dict1900_2000 = coding_for_project.dictOfLengthsMultiple(era1900_2000)

dict1700_1800,dict1800_1900,dict1900_2000
# Out:
# ({3: 0.2248676283478826,
#   7: 0.06655335814289427,
#   9: 0.033287028790949226,
#   5: 0.10527160923999714,
#   2: 0.18460453432313836,
#   8: 0.03970194767009657,
#   4: 0.1742344596496491,
#   6: 0.07797398249989705,
#   12: 0.004687590128550221,
#   10: 0.019988645835254743,
#   11: 0.009260366501764414,
#   1: 0.05658795359858285,
#   13: 0.0018251656780549162,
#   14: 0.0007814825415337414,
#   15: 0.00030769053072945653,
#   16: 5.356482314087171e-05,
#   18: 6.398111163303568e-06,
#   17: 6.09222301135629e-06,
#   20: 5.013637092892665e-07},
#  {3: 0.23579773933701237,
#   7: 0.06457606261880376,
#   9: 0.03237959359412721,
#   5: 0.10737199251789364,
#   2: 0.17339274420418518,
#   4: 0.1817130318297774,
#   6: 0.0812307186091042,
#   8: 0.03856138846231508,
#   12: 0.004479304797976927,
#   10: 0.018024369206333445,
#   1: 0.05180478890077478,
#   11: 0.007978244721535546,
#   13: 0.0016281200228486809,
#   14: 0.0007211470272777883,
#   15: 0.00026944861685511277,
# ...

# %%
def getDictDistance(dict1,dict2):
    distance = 0
    for key in dict1:
        if key < 10:
            distance += (dict1[key] + dict2[key])**2
    distance = distance ** 0.5
    return distance

getDictDistance(dict1700_1800,dict1800_1900),getDictDistance(dict1800_1900,dict1900_2000),getDictDistance(dict1700_1800,dict1900_2000)
# Can be seen that there is barely difference between 1900s and 2000s however whenever comparing to 1800s there is big difference. Maybe about renaissance and Age of Enlightenment "https://en.wikipedia.org/wiki/Age_of_Enlightenment"
# Out:
# (0.7596169126772853, 0.7647487777289699, 0.7594206447080719)

# %% [markdown]
# **Table when putting down max length of word**

# %%
from tabulate import tabulate
col_names = ["Max Length of word(not included)","1800s to 1900s","1900s to 2000s","1800s to 2000s"]
data = [[1,0,0,0],
        [2,0.10590832523632854,0.10853020973774866,0.111718021779734],
        [3,0.373199486396729,0.3521967794012928,0.36574697266501655],
        [4,0.588515518473875,0.5859058341334173,0.5853267003823254],
        [5,0.6890357205522395,0.6917274110100696, 0.6838090257694925],
        [6,0.7214950144719036, 0.7269498851876072, 0.7169636358547201],
        [7,0.7507680517856392, 0.7563537026325738, 0.7473934285798933],
        [8,0.7507680517856392, 0.7563537026325738, 0.7473934285798933],
        [9,0.7554420461155757, 0.7606613198758974, 0.7520427230263755],
        [10,0.7580512816832371, 0.7629448387245668, 0.7546228778988694],
        [11,0.7589088001849286, 0.7636402362321824, 0.7554942808137093]]
print(tabulate(data, headers=col_names, tablefmt="fancy_grid"))
# Out:
# ╒════════════════════════════════════╤══════════════════╤══════════════════╤══════════════════╕
# │   Max Length of word(not included) │   1800s to 1900s │   1900s to 2000s │   1800s to 2000s │
# ╞════════════════════════════════════╪══════════════════╪══════════════════╪══════════════════╡
# │                                  1 │         0        │         0        │         0        │
# ├────────────────────────────────────┼──────────────────┼──────────────────┼──────────────────┤
# │                                  2 │         0.105908 │         0.10853  │         0.111718 │
# ├────────────────────────────────────┼──────────────────┼──────────────────┼──────────────────┤
# │                                  3 │         0.373199 │         0.352197 │         0.365747 │
# ├────────────────────────────────────┼──────────────────┼──────────────────┼──────────────────┤
# │                                  4 │         0.588516 │         0.585906 │         0.585327 │
# ...

# %%
url1 = "https://www.gutenberg.org/cache/epub/36810/pg36810.txt"
randBookDict = coding_for_project.dictOfLengths(url1)
getDictDistance(randBookDict,dict1700_1800),getDictDistance(randBookDict,dict1800_1900),getDictDistance(randBookDict,dict1900_2000)
# Out:
# (0.768612839234791, 0.7735676606140038, 0.7732385383096457)

# %% [markdown]
# **Zip Law**
#
# **Find frequency of each word length**
#
# **Order by power \- highest to lowest**
#
# **Draw graph by log log of power and frequency**
#
# **See if there are differences and if era gets identification and can be identified.**

# %%
#Zip's Law
#https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4176592/

# %%
#dict1700_1800,dict1800_1900,dict1900_2000

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

def drawLogGraphWithTrendLine(orderedList):
    rank = []
    freq = []
    for i in range(1, 10):
        rank.append(math.log(i))
        freq.append(math.log(orderedList[i-1]))
    plt.scatter(rank, freq)
    
    slope, intercept, _, _, _ = stats.linregress(rank, freq)
    plt.plot(np.array(rank), slope*np.array(rank) + intercept, color='red', label='Trend Line')
    
    plt.legend()
    plt.show()
    
    return slope

# %%
coding_for_project.drawLogGraph(coding_for_project.orderDictByFrequency(dict1700_1800))

# %%
print(coding_for_project.drawLogGraphWithTrendLine(coding_for_project.orderDictByFrequency(dict1700_1800)))
# Out:
# -1.0923843430289824

# %%
coding_for_project.drawLogGraph(coding_for_project.orderDictByFrequency(dict1800_1900))

# %%
print(coding_for_project.drawLogGraphWithTrendLine(coding_for_project.orderDictByFrequency(dict1800_1900)))
# Out:
# -1.2950851560848426

# %%
coding_for_project.drawLogGraph(coding_for_project.orderDictByFrequency(dict1900_2000))

# %%
print(coding_for_project.drawLogGraphWithTrendLine(coding_for_project.orderDictByFrequency(dict1900_2000)))
# Out:
# -1.1988416443056225

# %% [markdown]
# **Find trend line of graphs and see if there is differences**
#
# **Use numpy.polyfit\(\)**

# %%
# Get random book and check trend line gradient and see if it is possible to identify which era book is from.
rand_url = 'https://gutenberg.org/cache/epub/73774/pg73774.txt' # "Piracy" : A romantic chronicle of these days by Michael Arlen written in the era 1900-2000
print(coding_for_project.drawLogGraphWithTrendLine(coding_for_project.orderDictByFrequency(coding_for_project.dictOfLengths(rand_url))))
# Out:
# -1.3412644426994536

# %%
rand_url2 = 'https://gutenberg.org/cache/epub/21364/pg21364.txt'
print(coding_for_project.drawLogGraphWithTrendLine(coding_for_project.orderDictByFrequency(coding_for_project.dictOfLengths(rand_url2)))) # The Rajah of Dah by George Manville Fenn written in the era 1800-1900
# Out:
# -1.470921797662035

# %%
rand_url3 = "https://gutenberg.org/cache/epub/32134/pg32134.txt" # From era 1900 - 2000
print(coding_for_project.drawLogGraphWithTrendLine(coding_for_project.orderDictByFrequency(coding_for_project.dictOfLengths(rand_url3))))
# Out:
# -1.0586296945858713
